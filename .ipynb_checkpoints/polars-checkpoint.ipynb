# %%
import polars as pl
import numpy as np
import math
import time

# %%
df = pl.read_parquet('./support/tyc2.parquet')
print(df)
# Out:
# shape: (2_430_468, 8)
# ┌────────────┬────────────┬────────┬─────────┬────────┬─────────┬───────────┬───────────┐
# │ RAmdeg     ┆ DEmdeg     ┆ BTmag  ┆ e_BTmag ┆ VTmag  ┆ e_VTmag ┆ HIPCCDM   ┆ Vmag      │
# │ ---        ┆ ---        ┆ ---    ┆ ---     ┆ ---    ┆ ---     ┆ ---       ┆ ---       │
# │ f32        ┆ f32        ┆ f32    ┆ f32     ┆ f32    ┆ f32     ┆ str       ┆ f32       │
# ╞════════════╪════════════╪════════╪═════════╪════════╪═════════╪═══════════╪═══════════╡
# │ 2.317505   ┆ 2.231843   ┆ 12.146 ┆ 0.158   ┆ 12.146 ┆ 0.223   ┆           ┆ 12.146    │
# │ 1.125582   ┆ 2.267394   ┆ 10.488 ┆ 0.038   ┆ 8.67   ┆ 0.015   ┆           ┆ 8.50638   │
# │ 1.056865   ┆ 1.897829   ┆ 12.921 ┆ 0.335   ┆ 12.1   ┆ 0.243   ┆           ┆ 12.026111 │
# │ 0.050598   ┆ 1.771443   ┆ 11.318 ┆ 0.07    ┆ 10.521 ┆ 0.051   ┆           ┆ 10.44927  │
# │ …          ┆ …          ┆ …      ┆ …       ┆ …      ┆ …       ┆ …         ┆ …         │
# │ 345.76767  ┆ -88.284042 ┆ 13.108 ┆ 0.271   ┆ 12.48  ┆ 0.196   ┆           ┆ 12.423479 │
# │ 341.197632 ┆ -88.538872 ┆ 13.147 ┆ 0.287   ┆ 12.158 ┆ 0.177   ┆           ┆ 12.06899  │
# │ 337.975433 ┆ -88.762932 ┆ 10.99  ┆ 0.048   ┆ 10.47  ┆ 0.042   ┆           ┆ 10.423201 │
# │ 355.96582  ┆ -88.834259 ┆ 12.828 ┆ 0.231   ┆ 12.096 ┆ 0.167   ┆           ┆ 12.03012  │
# └────────────┴────────────┴────────┴─────────┴────────┴─────────┴───────────┴───────────┘

# %%
# Add angular separation column to dataframe
# df = df.with_columns((pl.col("RAmdeg").radians()).alias("RA_rad"), (pl.col("DEmdeg").radians()).alias("DEC_rad")
#                     )

def stars_for_center_and_radius(df, center, radius, min_mag):
    ra, dec = center
    minra = ra - radius/2
    maxra = ra + radius/2
    mindec = dec - radius/2
    maxdec = dec + radius/2
    return df.filter((pl.col("RAmdeg") < maxra) & (pl.col("RAmdeg") > minra) & (pl.col("DEmdeg") < maxdec) & (pl.col("DEmdeg") > mindec) & (pl.col("Vmag") > min_mag))
    
res = stars_for_center_and_radius(df, [50,5], 2, 8)
print(res.min(), res.max())
print(res)
print(df.min(), df.max())
# Out:
# shape: (1, 10)
# ┌──────────┬──────────┬───────┬─────────┬───┬───────────┬──────────┬──────────┬─────────┐
# │ RAmdeg   ┆ DEmdeg   ┆ BTmag ┆ e_BTmag ┆ … ┆ HIPCCDM   ┆ Vmag     ┆ RA_rad   ┆ DEC_rad │
# │ ---      ┆ ---      ┆ ---   ┆ ---     ┆   ┆ ---       ┆ ---      ┆ ---      ┆ ---     │
# │ f32      ┆ f32      ┆ f32   ┆ f32     ┆   ┆ str       ┆ f32      ┆ f32      ┆ f32     │
# ╞══════════╪══════════╪═══════╪═════════╪═══╪═══════════╪══════════╪══════════╪═════════╡
# │ 49.05756 ┆ 4.011876 ┆ 9.871 ┆ 0.028   ┆ … ┆           ┆ 8.979381 ┆ 0.856216 ┆ 0.07002 │
# └──────────┴──────────┴───────┴─────────┴───┴───────────┴──────────┴──────────┴─────────┘ shape: (1, 10)
# ┌───────────┬──────────┬───────┬─────────┬───┬───────────┬─────────┬──────────┬──────────┐
# │ RAmdeg    ┆ DEmdeg   ┆ BTmag ┆ e_BTmag ┆ … ┆ HIPCCDM   ┆ Vmag    ┆ RA_rad   ┆ DEC_rad  │
# │ ---       ┆ ---      ┆ ---   ┆ ---     ┆   ┆ ---       ┆ ---     ┆ ---      ┆ ---      │
# │ f32       ┆ f32      ┆ f32   ┆ f32     ┆   ┆ str       ┆ f32     ┆ f32      ┆ f32      │
# ╞═══════════╪══════════╪═══════╪═════════╪═══╪═══════════╪═════════╪══════════╪══════════╡
# │ 50.991394 ┆ 5.998132 ┆ 14.41 ┆ 0.614   ┆ … ┆  15670    ┆ 13.1496 ┆ 0.889968 ┆ 0.104687 │
# └───────────┴──────────┴───────┴─────────┴───┴───────────┴─────────┴──────────┴──────────┘
# shape: (94, 10)
# ┌───────────┬──────────┬────────┬─────────┬───┬───────────┬───────────┬──────────┬──────────┐
# │ RAmdeg    ┆ DEmdeg   ┆ BTmag  ┆ e_BTmag ┆ … ┆ HIPCCDM   ┆ Vmag      ┆ RA_rad   ┆ DEC_rad  │
# │ ---       ┆ ---      ┆ ---    ┆ ---     ┆   ┆ ---       ┆ ---       ┆ ---      ┆ ---      │
# │ f32       ┆ f32      ┆ f32    ┆ f32     ┆   ┆ str       ┆ f32       ┆ f32      ┆ f32      │
# ╞═══════════╪══════════╪════════╪═════════╪═══╪═══════════╪═══════════╪══════════╪══════════╡
# │ 49.174763 ┆ 4.671556 ┆ 12.313 ┆ 0.189   ┆ … ┆           ┆ 11.80724  ┆ 0.858262 ┆ 0.081534 │
# │ 49.327896 ┆ 4.26476  ┆ 11.642 ┆ 0.085   ┆ … ┆           ┆ 10.988    ┆ 0.860934 ┆ 0.074434 │
# │ 49.568325 ┆ 4.895411 ┆ 13.475 ┆ 0.402   ┆ … ┆           ┆ 12.00568  ┆ 0.86513  ┆ 0.085441 │
# │ 49.097866 ┆ 4.744157 ┆ 10.982 ┆ 0.058   ┆ … ┆           ┆ 10.44681  ┆ 0.856919 ┆ 0.082801 │
# │ …         ┆ …        ┆ …      ┆ …       ┆ … ┆ …         ┆ …         ┆ …        ┆ …        │
# │ 50.101418 ┆ 5.696984 ┆ 13.306 ┆ 0.394   ┆ … ┆           ┆ 11.839951 ┆ 0.874435 ┆ 0.099431 │
# │ 50.608727 ┆ 5.009947 ┆ 12.876 ┆ 0.308   ┆ … ┆           ┆ 12.396399 ┆ 0.883289 ┆ 0.08744  │
# │ 50.325439 ┆ 5.186826 ┆ 12.108 ┆ 0.164   ┆ … ┆           ┆ 11.75811  ┆ 0.878345 ┆ 0.090527 │
# │ 50.284767 ┆ 5.923281 ┆ 11.662 ┆ 0.085   ┆ … ┆           ┆ 10.84777  ┆ 0.877635 ┆ 0.103381 │
# └───────────┴──────────┴────────┴─────────┴───┴───────────┴───────────┴──────────┴──────────┘
# shape: (1, 10)
# ┌──────────┬────────────┬───────┬─────────┬───┬───────────┬─────────┬──────────┬───────────┐
# │ RAmdeg   ┆ DEmdeg     ┆ BTmag ┆ e_BTmag ┆ … ┆ HIPCCDM   ┆ Vmag    ┆ RA_rad   ┆ DEC_rad   │
# │ ---      ┆ ---        ┆ ---   ┆ ---     ┆   ┆ ---       ┆ ---     ┆ ---      ┆ ---       │
# │ f32      ┆ f32        ┆ f32   ┆ f32     ┆   ┆ str       ┆ f32     ┆ f32      ┆ f32       │
# ╞══════════╪════════════╪═══════╪═════════╪═══╪═══════════╪═════════╪══════════╪═══════════╡
# │ 0.000339 ┆ -89.889664 ┆ 2.41  ┆ 0.014   ┆ … ┆           ┆ 1.89558 ┆ 0.000006 ┆ -1.568871 │
# └──────────┴────────────┴───────┴─────────┴───┴───────────┴─────────┴──────────┴───────────┘ shape: (1, 10)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬──────────┬──────────┬─────────┐
# │ RAmdeg     ┆ DEmdeg    ┆ BTmag     ┆ e_BTmag ┆ … ┆ HIPCCDM   ┆ Vmag     ┆ RA_rad   ┆ DEC_rad │
# │ ---        ┆ ---       ┆ ---       ┆ ---     ┆   ┆ ---       ┆ ---      ┆ ---      ┆ ---     │
# │ f32        ┆ f32       ┆ f32       ┆ f32     ┆   ┆ str       ┆ f32      ┆ f32      ┆ f32     │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪══════════╪══════════╪═════════╡
# │ 359.999878 ┆ 89.832336 ┆ 16.580999 ┆ 1.977   ┆ … ┆ 120404    ┆ 15.37354 ┆ 6.283183 ┆ 1.56787 │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴──────────┴──────────┴─────────┘

# %%
RA_values = [ra for ra in range(0, 361, 4)]  # Increment by 4 for a 2-degree radius
Dec_values = [dec for dec in range(-90, 91, 4)]  # Increment by 4 for a 2-degree radius

grid_points = [(ra, dec) for ra in RA_values for dec in Dec_values]

# Print the grid points
for point in grid_points:
    stars = stars_for_center_and_radius(df, point, 2, 8)
    print(stars)
    time.sleep(10)
# Out:
# shape: (0, 10)
# ┌────────┬────────┬───────┬─────────┬───┬─────────┬──────┬────────┬─────────┐
# │ RAmdeg ┆ DEmdeg ┆ BTmag ┆ e_BTmag ┆ … ┆ HIPCCDM ┆ Vmag ┆ RA_rad ┆ DEC_rad │
# │ ---    ┆ ---    ┆ ---   ┆ ---     ┆   ┆ ---     ┆ ---  ┆ ---    ┆ ---     │
# │ f32    ┆ f32    ┆ f32   ┆ f32     ┆   ┆ str     ┆ f32  ┆ f32    ┆ f32     │
# ╞════════╪════════╪═══════╪═════════╪═══╪═════════╪══════╪════════╪═════════╡
# └────────┴────────┴───────┴─────────┴───┴─────────┴──────┴────────┴─────────┘
# shape: (9, 10)
# ┌──────────┬────────────┬────────┬─────────┬───┬───────────┬───────────┬──────────┬───────────┐
# │ RAmdeg   ┆ DEmdeg     ┆ BTmag  ┆ e_BTmag ┆ … ┆ HIPCCDM   ┆ Vmag      ┆ RA_rad   ┆ DEC_rad   │
# │ ---      ┆ ---        ┆ ---    ┆ ---     ┆   ┆ ---       ┆ ---       ┆ ---      ┆ ---       │
# │ f32      ┆ f32        ┆ f32    ┆ f32     ┆   ┆ str       ┆ f32       ┆ f32      ┆ f32       │
# ╞══════════╪════════════╪════════╪═════════╪═══╪═══════════╪═══════════╪══════════╪═══════════╡
# │ 0.971985 ┆ -85.889214 ┆ 13.942 ┆ 0.362   ┆ … ┆           ┆ 12.28193  ┆ 0.016964 ┆ -1.49905  │
# │ 0.519872 ┆ -86.132851 ┆ 13.379 ┆ 0.288   ┆ … ┆           ┆ 11.96091  ┆ 0.009073 ┆ -1.503302 │
# │ 0.740956 ┆ -85.642769 ┆ 11.578 ┆ 0.058   ┆ … ┆           ┆ 9.892859  ┆ 0.012932 ┆ -1.494748 │
# │ 0.101008 ┆ -85.723114 ┆ 13.324 ┆ 0.27    ┆ … ┆           ┆ 11.275889 ┆ 0.001763 ┆ -1.496151 │
# │ 0.254737 ┆ -85.683899 ┆ 13.159 ┆ 0.24    ┆ … ┆           ┆ 12.1453   ┆ 0.004446 ┆ -1.495466 │
# │ 0.949719 ┆ -85.258797 ┆ 12.549 ┆ 0.178   ┆ … ┆           ┆ 11.76965  ┆ 0.016576 ┆ -1.488047 │
# │ 0.516081 ┆ -85.468979 ┆ 13.586 ┆ 0.306   ┆ … ┆           ┆ 11.86489  ┆ 0.009007 ┆ -1.491715 │
# │ 0.87115  ┆ -86.25631  ┆ 10.997 ┆ 0.042   ┆ … ┆           ┆ 10.6918   ┆ 0.015204 ┆ -1.505457 │
# │ 0.295437 ┆ -86.290779 ┆ 12.774 ┆ 0.208   ┆ … ┆           ┆ 11.81807  ┆ 0.005156 ┆ -1.506058 │
# └──────────┴────────────┴────────┴─────────┴───┴───────────┴───────────┴──────────┴───────────┘
# shape: (7, 10)
# ┌──────────┬────────────┬────────┬─────────┬───┬───────────┬───────────┬──────────┬───────────┐
# │ RAmdeg   ┆ DEmdeg     ┆ BTmag  ┆ e_BTmag ┆ … ┆ HIPCCDM   ┆ Vmag      ┆ RA_rad   ┆ DEC_rad   │
# │ ---      ┆ ---        ┆ ---    ┆ ---     ┆   ┆ ---       ┆ ---       ┆ ---      ┆ ---       │
# │ f32      ┆ f32        ┆ f32    ┆ f32     ┆   ┆ str       ┆ f32       ┆ f32      ┆ f32       │
# ╞══════════╪════════════╪════════╪═════════╪═══╪═══════════╪═══════════╪══════════╪═══════════╡
# │ 0.87583  ┆ -82.295334 ┆ 12.753 ┆ 0.219   ┆ … ┆           ┆ 12.00417  ┆ 0.015286 ┆ -1.436324 │
# │ 0.739003 ┆ -82.486908 ┆ 11.95  ┆ 0.086   ┆ … ┆           ┆ 11.09108  ┆ 0.012898 ┆ -1.439668 │
# │ 0.852151 ┆ -82.212036 ┆ 13.194 ┆ 0.297   ┆ … ┆           ┆ 11.88927  ┆ 0.014873 ┆ -1.434871 │
# │ 0.21712  ┆ -81.353371 ┆ 12.628 ┆ 0.186   ┆ … ┆           ┆ 12.86344  ┆ 0.003789 ┆ -1.419884 │
# │ 0.313139 ┆ -81.226074 ┆ 12.401 ┆ 0.149   ┆ … ┆           ┆ 11.391661 ┆ 0.005465 ┆ -1.417662 │
# │ 0.503752 ┆ -81.283218 ┆ 10.459 ┆ 0.029   ┆ … ┆           ┆ 10.04807  ┆ 0.008792 ┆ -1.41866  │
# │ 0.927681 ┆ -82.689911 ┆ 10.938 ┆ 0.04    ┆ … ┆           ┆ 10.14121  ┆ 0.016191 ┆ -1.443211 │
# └──────────┴────────────┴────────┴─────────┴───┴───────────┴───────────┴──────────┴───────────┘
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       8 stars = stars_for_center_and_radius(df, point, 2, 8)
#       9 print(stars)
# ---> 10 time.sleep(10)
#
# KeyboardInterrupt:
